# %% [markdown]
# <a href="https://colab.research.google.com/github/klaywittler/machine-perception/blob/master/project4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Run the next code block. There will be two separate authentications needed. The first will download all extra files from the CIS580 shared drive files. The second connects your google drive to save files to 'cis580-2019-hw6'

# %%
# bootstrap environment into place
from google.colab import auth
auth.authenticate_user()

from googleapiclient.discovery import build
drive_service = build('drive', 'v3')

import io
import os
from googleapiclient.http import MediaIoBaseDownload

def download_file(fn, file_id):
    request = drive_service.files().get_media(fileId=file_id)
    downloaded = io.BytesIO()
    downloader = MediaIoBaseDownload(downloaded, request)
    done = False
    while done is False:
        # _ is a placeholder for a progress object that we ignore.
        # (Our file is small, so we skip reporting progress.)
        _, done = downloader.next_chunk()
    
    downloaded.seek(0)

    folder = fn.split('/')
    if len(folder) > 1:
        os.makedirs(folder[0], exist_ok=True)

    with open(fn, 'wb') as f:
        f.write(downloaded.read())

id_to_fn = {
        '1PIhom4rR_a_vm-zCt_1rYKbz8sd43Gel': "data/images.npz",
        '1IOxsTUF-MgmDRp3-0jPMJ-qo8yLZFCez': "data/train_data.npz",
        '1ZPRZoiuQVwWm88dWB4kWTBTtSQKBaDxs': "data/valid_data.npz",
        '1rJgn9NHdnwToyIERWbS8g_gZu19wAkkd': "data/kpt.npy",
        '1noGbThisv1HOi87dG66AfgQzpIv0o1y6': "data/misc_data.npz",
        '1Jp94eNQyXlTBYhqFFksbwRRl9VOGLAYT': "utils/__init__.py",
        '1UCCx78ZFL-BxsIScl0YkaLSRjw6Umliu': "utils/pose_utils.py",
        '1lV3oSGB2ygBj0vF2zaj_FKVaExz4-loi': "utils/plotting.py",
        '1td00aFXojVptGMz1XRTuVWSdpAHYi4lt': "utils/train_options.py",
        '18NNIqvS5-GB9xGWJX0wjHeC_RaaoKnWz': "hourglass.py",
        '1mJS9HFhDoUR1XGxRNQm2e-j4WZQn7Zhl': "dataset.py",
           }

# download all files into the vm
for fid, fn in id_to_fn.items():
    download_file(fn, fid)

# mount the user's google drive into the system
from google.colab import drive
drive.mount('/content/gdrive')
# create folder to write data to
os.makedirs('/content/gdrive/My Drive/cis580-2019-hw6', exist_ok=True)
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %% [markdown]
# The next code block handles the external library imports.

# %%
from __future__ import division
from __future__ import print_function

import torch
from torch.utils.data import DataLoader
from torchvision import transforms
from torchvision.utils import make_grid

from hourglass import hg

from dataset import Dataset
from dataset import RandomFlipLR, RandomRescaleBB, RandomRotation,\
                    CropAndPad, LocsToHeatmaps,\
                    ToTensor, Normalize, Denormalize
from utils import TrainOptions, PoseUtils

from tqdm import tqdm
from PIL import Image
import os
from time import time
import numpy as np

# %% [markdown]
# Step 1) The Trainer class contains two locations where you must implement the training step and the test step as specified in the accompanying PDF

# %%
class Trainer(object):

    def __init__(self, options):
        self.options = options
        self.device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

        train_transform_list = []
        train_transform_list.append(RandomRescaleBB(0.8, 1.2))
        train_transform_list.append(RandomFlipLR())
        train_transform_list.append(RandomRotation(degrees=options.degrees))
        train_transform_list.append(CropAndPad(out_size=(options.crop_size, options.crop_size)))
        train_transform_list.append(LocsToHeatmaps(out_size=(options.heatmap_size, options.heatmap_size)))
        train_transform_list.append(ToTensor())
        train_transform_list.append(Normalize())
        test_transform_list = [CropAndPad(out_size=(options.crop_size, options.crop_size))]
        test_transform_list.append(LocsToHeatmaps(out_size=(options.heatmap_size, options.heatmap_size)))
        test_transform_list.append(ToTensor())
        test_transform_list.append(Normalize())
        self.train_ds = Dataset(is_train=True, transform=transforms.Compose(train_transform_list))
        self.test_ds = Dataset(is_train=False, transform=transforms.Compose(test_transform_list))

        self.model = hg(num_stacks=options.num_stacks, num_blocks=options.num_blocks, num_classes=options.num_classes).to(self.device)
        # define loss function and optimizer
        self.heatmap_loss = torch.nn.MSELoss().to(self.device) # for Global loss
        self.optimizer = torch.optim.RMSprop(self.model.parameters(),
                                             lr = options.lr)


        self.pose_utils = PoseUtils(detection_thresh=options.detection_thresh, dist_thresh=options.dist_thresh)

        self.train_data_loader = DataLoader(self.train_ds, batch_size=options.batch_size,
                                            num_workers=options.num_workers,
                                            pin_memory=True,
                                            shuffle=True)
        self.test_data_loader = DataLoader(self.test_ds, batch_size=options.test_batch_size,
                                           num_workers=options.num_workers,
                                           pin_memory=True,
                                           shuffle=True)

        self.summary_iters = []
        self.losses = []
        self.pcks = []

    def train(self):
        self.total_step_count = 0
        start_time = time()
        for epoch in range(1,self.options.num_epochs+1):
            elapsed_time = time() - start_time
            seconds_per_epoch = elapsed_time / epoch
            remaining_time = (self.options.num_epochs - epoch) * seconds_per_epoch

            print("Epoch %d/%d - Elapsed Time %f - Remaining Time %f" %
                    (epoch, self.options.num_epochs,
                        elapsed_time, remaining_time))

            for step, batch in enumerate(self.train_data_loader):
                self.model.train()
                batch = {k: v.to(self.device) if isinstance(v, torch.Tensor) else v for k,v in batch.items()}
                """
                ADD YOUR CODE FOR THE TRAINING STEP HERE
                You have to name the output of your neural network pred_heatmap_list
                This list contains the output heatmaps for each stack of the Stacked Hourglass model
                Since we are using only 1 stack in this homework, pred_heatmap_list will contain only 1 tensor
                """
                inputs = batch['image']
                labels = batch['keypoint_heatmaps'] # keypoint_locs
#                 print(batch)
                
                self.optimizer.zero_grad()
            
                pred_heatmap_list = self.model(inputs)
                loss = self.heatmap_loss(pred_heatmap_list[-1], labels)
                loss.backward()
                self.optimizer.step()
                
                self.total_step_count += 1
                if self.total_step_count % self.options.summary_steps == 0:
                    self.save_summaries(batch, pred_heatmap_list[-1].detach(), loss.detach(), mode='train')
                if self.total_step_count % self.options.test_steps == 0:
                    self.model.eval()
                    batch = next(iter(self.test_data_loader))
                    batch = {k: v.to(self.device) if isinstance(v, torch.Tensor) else v for k,v in batch.items()}
                    """
                    ADD YOUR CODE FOR THE TEST STEP HERE
                    What you have to do is to perform a forward pass and record the loss and the output
                    """
                    inputs = batch['image']
                    labels = batch['keypoint_heatmaps']
                    with torch.no_grad():
                        pred_heatmap_list = self.model(inputs)
                        loss = self.heatmap_loss(pred_heatmap_list[-1], labels)
                    self.save_summaries(batch, pred_heatmap_list[-1].detach(), loss.detach(), mode='test')

        checkpoint = {'model': self.model.state_dict()}
        torch.save(checkpoint, '/content/gdrive/My Drive/cis580-2019-hw6/model_checkpoint.pt')

    def save_summaries(self, batch, pred_heatmaps, loss, mode='train'):
        gt_heatmaps = batch['keypoint_heatmaps'].to(self.device)
        pck = self.pose_utils.pck(gt_heatmaps, pred_heatmaps)

        batch = Denormalize()(batch)
        images = batch['image']

        gt_image_keypoints, pred_image_keypoints = self.pose_utils.draw_keypoints_with_labels(images, gt_heatmaps, pred_heatmaps)

        gt_image_keypoints_grid = make_grid(gt_image_keypoints, pad_value=1, nrow=3)
        pred_image_keypoints_grid = make_grid(pred_image_keypoints, pad_value=1, nrow=3)

        pred_heatmaps_grid = make_grid(pred_heatmaps[0,:,:,:].unsqueeze(0).transpose(0,1), pad_value=1, nrow=5)
        pred_heatmaps_grid[pred_heatmaps_grid > 1] = 1
        pred_heatmaps_grid[pred_heatmaps_grid < 0] = 0

        self.losses.append(loss)
        self.pcks.append(pck)
        self.summary_iters.append(self.total_step_count)

        folder = '/content/gdrive/My Drive/cis580-2019-hw6/logs/%d' % self.total_step_count
        os.makedirs(folder, exist_ok=True)

        gt_ikg = Image.fromarray((gt_image_keypoints_grid.cpu().detach().numpy().transpose(1,2,0) * 255.).astype(np.uint8))
        pred_ikg = Image.fromarray((pred_image_keypoints_grid.cpu().detach().numpy().transpose(1,2,0) * 255.).astype(np.uint8))
        pred_hg = Image.fromarray((pred_heatmaps_grid.cpu().detach().numpy().transpose(1,2,0) * 255.).astype(np.uint8))

        gt_ikg.save(os.path.join(folder, mode + '_gt_image_keypoints.jpg'))
        pred_ikg.save(os.path.join(folder, mode + '_pred_image_keypoints.jpg'))
        pred_hg.save(os.path.join(folder, mode + '_pred_heatmaps.jpg'))

# %% [markdown]
# The next block will start the training process. Be sure to run the above block first every time you want to test changes to the code.

# %%
options = TrainOptions().parse_args(["--name=gascan",
                                     "--summary_steps=200",
                                     "--num_epochs=400",
                                     "--test_steps=1000"])
trainer = Trainer(options)
trainer.train()
# Out:
# Epoch 1/400 - Elapsed Time 0.000002 - Remaining Time 0.000951
# Epoch 2/400 - Elapsed Time 5.336092 - Remaining Time 1061.882354
# Epoch 3/400 - Elapsed Time 10.713276 - Remaining Time 1417.723512
# Epoch 4/400 - Elapsed Time 16.110254 - Remaining Time 1594.915104
# Epoch 5/400 - Elapsed Time 21.716395 - Remaining Time 1715.595178
# Epoch 6/400 - Elapsed Time 26.885192 - Remaining Time 1765.460952
# Epoch 7/400 - Elapsed Time 32.136156 - Remaining Time 1804.215607
# Epoch 8/400 - Elapsed Time 37.603729 - Remaining Time 1842.582710
# Epoch 9/400 - Elapsed Time 42.933553 - Remaining Time 1865.224368
# Epoch 10/400 - Elapsed Time 48.806469 - Remaining Time 1903.452299
# Epoch 11/400 - Elapsed Time 54.315447 - Remaining Time 1920.791720
# Epoch 12/400 - Elapsed Time 59.676563 - Remaining Time 1929.542204
# Epoch 13/400 - Elapsed Time 65.100133 - Remaining Time 1937.980888
# Epoch 14/400 - Elapsed Time 70.343435 - Remaining Time 1939.469001
# Epoch 15/400 - Elapsed Time 75.571542 - Remaining Time 1939.669573
# Epoch 16/400 - Elapsed Time 80.912107 - Remaining Time 1941.890574
# Epoch 17/400 - Elapsed Time 86.404188 - Remaining Time 1946.635522
# Epoch 18/400 - Elapsed Time 91.738461 - Remaining Time 1946.894001
# Epoch 19/400 - Elapsed Time 97.045178 - Remaining Time 1946.011200
# Epoch 20/400 - Elapsed Time 102.152632 - Remaining Time 1940.899999
# Epoch 21/400 - Elapsed Time 107.505514 - Remaining Time 1940.218565
# Epoch 22/400 - Elapsed Time 113.006690 - Remaining Time 1941.660393
# Epoch 23/400 - Elapsed Time 118.810237 - Remaining Time 1947.454753
# Epoch 24/400 - Elapsed Time 124.047021 - Remaining Time 1943.403328
# Epoch 25/400 - Elapsed Time 130.129449 - Remaining Time 1951.941737
# Epoch 26/400 - Elapsed Time 135.744433 - Remaining Time 1952.631462
# Epoch 27/400 - Elapsed Time 140.964745 - Remaining Time 1947.401845
# Epoch 28/400 - Elapsed Time 146.187261 - Remaining Time 1942.202177
# Epoch 29/400 - Elapsed Time 151.405016 - Remaining Time 1936.940029
# Epoch 30/400 - Elapsed Time 156.750547 - Remaining Time 1933.256751
# Epoch 31/400 - Elapsed Time 162.085935 - Remaining Time 1929.345486
# Epoch 32/400 - Elapsed Time 167.469963 - Remaining Time 1925.904575
# Epoch 33/400 - Elapsed Time 173.045659 - Remaining Time 1924.477478
# Epoch 34/400 - Elapsed Time 178.258699 - Remaining Time 1918.902465
# Epoch 35/400 - Elapsed Time 183.534736 - Remaining Time 1914.005106
# Epoch 36/400 - Elapsed Time 188.757343 - Remaining Time 1908.546469
# Epoch 37/400 - Elapsed Time 194.003780 - Remaining Time 1903.334379
# Epoch 38/400 - Elapsed Time 199.873780 - Remaining Time 1904.060751
# Epoch 39/400 - Elapsed Time 205.822151 - Remaining Time 1905.174271
# Epoch 40/400 - Elapsed Time 211.827903 - Remaining Time 1906.451125
# Epoch 41/400 - Elapsed Time 217.061519 - Remaining Time 1900.611840
# Epoch 42/400 - Elapsed Time 222.235043 - Remaining Time 1894.289172
# Epoch 43/400 - Elapsed Time 227.433841 - Remaining Time 1888.229798
# Epoch 44/400 - Elapsed Time 233.167445 - Remaining Time 1886.536600
# Epoch 45/400 - Elapsed Time 238.294179 - Remaining Time 1879.876303
# Epoch 46/400 - Elapsed Time 243.526441 - Remaining Time 1874.094786
# Epoch 47/400 - Elapsed Time 248.804093 - Remaining Time 1868.677547
# Epoch 48/400 - Elapsed Time 254.072617 - Remaining Time 1863.199190
# Epoch 49/400 - Elapsed Time 259.233593 - Remaining Time 1856.959005
# Epoch 50/400 - Elapsed Time 264.784631 - Remaining Time 1853.492420
# Epoch 51/400 - Elapsed Time 269.971149 - Remaining Time 1847.449631
# Epoch 52/400 - Elapsed Time 275.075289 - Remaining Time 1840.888469
# Epoch 53/400 - Elapsed Time 280.395190 - Remaining Time 1835.794922
# Epoch 54/400 - Elapsed Time 288.085505 - Remaining Time 1845.881202
# Epoch 55/400 - Elapsed Time 293.773885 - Remaining Time 1842.763458
# Epoch 56/400 - Elapsed Time 299.030104 - Remaining Time 1836.899208
# Epoch 57/400 - Elapsed Time 304.178796 - Remaining Time 1830.409246
# Epoch 58/400 - Elapsed Time 309.487522 - Remaining Time 1824.909182
# Epoch 59/400 - Elapsed Time 314.790445 - Remaining Time 1819.382061
# Epoch 60/400 - Elapsed Time 320.104097 - Remaining Time 1813.923216
# Epoch 61/400 - Elapsed Time 325.651617 - Remaining Time 1809.768821
# Epoch 62/400 - Elapsed Time 331.164520 - Remaining Time 1805.380769
# Epoch 63/400 - Elapsed Time 336.276020 - Remaining Time 1798.809823
# Epoch 64/400 - Elapsed Time 341.497762 - Remaining Time 1792.863249
# Epoch 65/400 - Elapsed Time 347.289156 - Remaining Time 1789.874881
# Epoch 66/400 - Elapsed Time 352.567307 - Remaining Time 1784.204249
# Epoch 67/400 - Elapsed Time 357.970725 - Remaining Time 1779.167932
# Epoch 68/400 - Elapsed Time 363.271342 - Remaining Time 1773.618904
# Epoch 69/400 - Elapsed Time 369.057298 - Remaining Time 1770.405298
# Epoch 70/400 - Elapsed Time 375.018436 - Remaining Time 1767.944055
# Epoch 71/400 - Elapsed Time 380.358045 - Remaining Time 1762.504180
# Epoch 72/400 - Elapsed Time 385.450209 - Remaining Time 1755.939841
# Epoch 73/400 - Elapsed Time 390.808249 - Remaining Time 1750.606816
# Epoch 74/400 - Elapsed Time 395.981692 - Remaining Time 1744.459885
# Epoch 75/400 - Elapsed Time 401.689060 - Remaining Time 1740.652593
# Epoch 76/400 - Elapsed Time 407.194975 - Remaining Time 1735.936472
# Epoch 77/400 - Elapsed Time 412.396766 - Remaining Time 1729.924097
# Epoch 78/400 - Elapsed Time 417.581684 - Remaining Time 1723.862849
# Epoch 79/400 - Elapsed Time 422.884263 - Remaining Time 1718.301880
# Epoch 80/400 - Elapsed Time 428.067709 - Remaining Time 1712.270836
# Epoch 81/400 - Elapsed Time 433.569831 - Remaining Time 1707.515753
# Epoch 82/400 - Elapsed Time 438.913674 - Remaining Time 1702.128640
# Epoch 83/400 - Elapsed Time 444.317475 - Remaining Time 1696.971561
# Epoch 84/400 - Elapsed Time 450.068987 - Remaining Time 1693.116665
# Epoch 85/400 - Elapsed Time 455.785217 - Remaining Time 1689.086393
# Epoch 86/400 - Elapsed Time 461.491163 - Remaining Time 1684.979361
# Epoch 87/400 - Elapsed Time 466.840725 - Remaining Time 1679.553414
# Epoch 88/400 - Elapsed Time 471.938533 - Remaining Time 1673.236617
# Epoch 89/400 - Elapsed Time 477.104008 - Remaining Time 1667.183667
# Epoch 90/400 - Elapsed Time 482.246463 - Remaining Time 1661.071151
# Epoch 91/400 - Elapsed Time 487.450402 - Remaining Time 1655.188729
# Epoch 92/400 - Elapsed Time 492.618109 - Remaining Time 1649.199757
# Epoch 93/400 - Elapsed Time 498.169056 - Remaining Time 1644.493551
# Epoch 94/400 - Elapsed Time 503.353278 - Remaining Time 1638.575564
# Epoch 95/400 - Elapsed Time 509.101473 - Remaining Time 1634.483676
# Epoch 96/400 - Elapsed Time 515.217581 - Remaining Time 1631.522338
# Epoch 97/400 - Elapsed Time 520.291666 - Remaining Time 1625.240978
# Epoch 98/400 - Elapsed Time 525.489612 - Remaining Time 1619.365948
# Epoch 99/400 - Elapsed Time 531.319008 - Remaining Time 1615.424460
# Epoch 100/400 - Elapsed Time 536.938398 - Remaining Time 1610.815194
# Epoch 101/400 - Elapsed Time 542.150553 - Remaining Time 1604.980351
# Epoch 102/400 - Elapsed Time 547.739744 - Remaining Time 1600.259253
# Epoch 103/400 - Elapsed Time 553.003685 - Remaining Time 1594.583441
# Epoch 104/400 - Elapsed Time 558.393624 - Remaining Time 1589.274161
# Epoch 105/400 - Elapsed Time 563.661849 - Remaining Time 1583.621384
# Epoch 106/400 - Elapsed Time 568.850296 - Remaining Time 1577.754594
# Epoch 107/400 - Elapsed Time 576.379249 - Remaining Time 1578.309532
# Epoch 108/400 - Elapsed Time 581.453200 - Remaining Time 1572.077169
# Epoch 109/400 - Elapsed Time 586.710678 - Remaining Time 1566.356029
# Epoch 110/400 - Elapsed Time 591.928144 - Remaining Time 1560.537835
# Epoch 111/400 - Elapsed Time 597.127128 - Remaining Time 1554.682342
# Epoch 112/400 - Elapsed Time 602.399684 - Remaining Time 1549.027758
# Epoch 113/400 - Elapsed Time 607.878909 - Remaining Time 1543.904839
# Epoch 114/400 - Elapsed Time 613.713257 - Remaining Time 1539.666593
# Epoch 115/400 - Elapsed Time 619.097559 - Remaining Time 1534.285255
# Epoch 116/400 - Elapsed Time 624.271748 - Remaining Time 1528.389453
# Epoch 117/400 - Elapsed Time 629.928004 - Remaining Time 1523.672009
# Epoch 118/400 - Elapsed Time 635.519004 - Remaining Time 1518.782705
# Epoch 119/400 - Elapsed Time 640.791234 - Remaining Time 1513.128879
# Epoch 120/400 - Elapsed Time 645.968016 - Remaining Time 1507.258704
# Epoch 121/400 - Elapsed Time 651.083632 - Remaining Time 1501.258954
# Epoch 122/400 - Elapsed Time 656.276443 - Remaining Time 1495.449600
# Epoch 123/400 - Elapsed Time 661.678135 - Remaining Time 1490.120677
# Epoch 124/400 - Elapsed Time 666.923874 - Remaining Time 1484.443462
# Epoch 125/400 - Elapsed Time 672.096042 - Remaining Time 1478.611292
# Epoch 126/400 - Elapsed Time 677.294714 - Remaining Time 1472.847236
# Epoch 127/400 - Elapsed Time 682.418825 - Remaining Time 1466.931806
# Epoch 128/400 - Elapsed Time 688.053520 - Remaining Time 1462.113731
# Epoch 129/400 - Elapsed Time 693.747553 - Remaining Time 1457.407650
# Epoch 130/400 - Elapsed Time 699.149054 - Remaining Time 1452.078805
# Epoch 131/400 - Elapsed Time 704.450215 - Remaining Time 1446.542808
# Epoch 132/400 - Elapsed Time 709.785925 - Remaining Time 1441.080515
# Epoch 133/400 - Elapsed Time 714.979457 - Remaining Time 1435.334700
# Epoch 134/400 - Elapsed Time 720.050066 - Remaining Time 1429.353117
# Epoch 135/400 - Elapsed Time 725.187979 - Remaining Time 1423.517144
# Epoch 136/400 - Elapsed Time 730.408925 - Remaining Time 1417.852618
# Epoch 137/400 - Elapsed Time 735.576461 - Remaining Time 1412.092038
# Epoch 138/400 - Elapsed Time 741.140440 - Remaining Time 1407.092718
# Epoch 139/400 - Elapsed Time 746.301820 - Remaining Time 1401.329317
# Epoch 140/400 - Elapsed Time 751.465543 - Remaining Time 1395.578865
# Epoch 141/400 - Elapsed Time 756.746411 - Remaining Time 1390.051919
# Epoch 142/400 - Elapsed Time 762.024530 - Remaining Time 1384.523443
# Epoch 143/400 - Elapsed Time 767.205333 - Remaining Time 1378.823570
# Epoch 144/400 - Elapsed Time 772.895581 - Remaining Time 1374.036588
# Epoch 145/400 - Elapsed Time 778.573307 - Remaining Time 1369.215126
# Epoch 146/400 - Elapsed Time 783.767193 - Remaining Time 1363.540184
# Epoch 147/400 - Elapsed Time 788.945709 - Remaining Time 1357.845335
# Epoch 148/400 - Elapsed Time 794.220673 - Remaining Time 1352.321687
# Epoch 149/400 - Elapsed Time 799.900746 - Remaining Time 1347.483806
# Epoch 150/400 - Elapsed Time 805.187260 - Remaining Time 1341.978766
# Epoch 151/400 - Elapsed Time 810.237221 - Remaining Time 1336.086543
# Epoch 152/400 - Elapsed Time 815.495655 - Remaining Time 1330.545542
# Epoch 153/400 - Elapsed Time 821.422187 - Remaining Time 1326.086798
# Epoch 154/400 - Elapsed Time 826.770074 - Remaining Time 1320.684664
# Epoch 155/400 - Elapsed Time 831.927112 - Remaining Time 1314.981564
# Epoch 156/400 - Elapsed Time 836.950256 - Remaining Time 1309.076042
# Epoch 157/400 - Elapsed Time 842.221279 - Remaining Time 1303.565419
# Epoch 158/400 - Elapsed Time 847.374458 - Remaining Time 1297.877335
# Epoch 159/400 - Elapsed Time 855.647804 - Remaining Time 1296.925288
# Epoch 160/400 - Elapsed Time 860.950833 - Remaining Time 1291.426250
# Epoch 161/400 - Elapsed Time 866.204724 - Remaining Time 1285.856702
# Epoch 162/400 - Elapsed Time 871.711198 - Remaining Time 1280.662130
# Epoch 163/400 - Elapsed Time 876.859004 - Remaining Time 1274.942233
# Epoch 164/400 - Elapsed Time 882.006425 - Remaining Time 1269.228757
# Epoch 165/400 - Elapsed Time 887.271397 - Remaining Time 1263.689565
# Epoch 166/400 - Elapsed Time 892.744684 - Remaining Time 1258.447326
# Epoch 167/400 - Elapsed Time 898.485981 - Remaining Time 1253.576250
# Epoch 168/400 - Elapsed Time 904.299365 - Remaining Time 1248.794361
# Epoch 169/400 - Elapsed Time 910.116451 - Remaining Time 1244.005327
# Epoch 170/400 - Elapsed Time 915.525243 - Remaining Time 1238.651799
# Epoch 171/400 - Elapsed Time 920.882421 - Remaining Time 1233.228505
# Epoch 172/400 - Elapsed Time 925.965810 - Remaining Time 1227.443051
# Epoch 173/400 - Elapsed Time 931.649503 - Remaining Time 1222.453393
# Epoch 174/400 - Elapsed Time 937.429637 - Remaining Time 1217.581023
# Epoch 175/400 - Elapsed Time 942.671509 - Remaining Time 1212.006226
# Epoch 176/400 - Elapsed Time 947.723952 - Remaining Time 1206.194120
# Epoch 177/400 - Elapsed Time 952.773701 - Remaining Time 1200.387206
# Epoch 178/400 - Elapsed Time 957.807716 - Remaining Time 1194.569173
# Epoch 179/400 - Elapsed Time 962.803513 - Remaining Time 1188.712717
# Epoch 180/400 - Elapsed Time 968.133811 - Remaining Time 1183.274658
# Epoch 181/400 - Elapsed Time 973.307780 - Remaining Time 1177.648640
# Epoch 182/400 - Elapsed Time 978.492342 - Remaining Time 1172.040278
# Epoch 183/400 - Elapsed Time 983.905409 - Remaining Time 1166.707507
# Epoch 184/400 - Elapsed Time 989.252509 - Remaining Time 1161.296423
# Epoch 185/400 - Elapsed Time 994.421419 - Remaining Time 1155.678947
# Epoch 186/400 - Elapsed Time 999.792402 - Remaining Time 1150.298785
# Epoch 187/400 - Elapsed Time 1004.851752 - Remaining Time 1144.563760
# Epoch 188/400 - Elapsed Time 1010.103180 - Remaining Time 1139.052522
# Epoch 189/400 - Elapsed Time 1015.891655 - Remaining Time 1134.143594
# Epoch 190/400 - Elapsed Time 1021.399020 - Remaining Time 1128.914706
# Epoch 191/400 - Elapsed Time 1026.841586 - Remaining Time 1123.611998
# Epoch 192/400 - Elapsed Time 1031.876676 - Remaining Time 1117.866399
# Epoch 193/400 - Elapsed Time 1037.061012 - Remaining Time 1112.288236
# Epoch 194/400 - Elapsed Time 1042.240588 - Remaining Time 1106.709078
# Epoch 195/400 - Elapsed Time 1047.302838 - Remaining Time 1101.010675
# Epoch 196/400 - Elapsed Time 1052.694963 - Remaining Time 1095.662105
# Epoch 197/400 - Elapsed Time 1058.164976 - Remaining Time 1090.393351
# Epoch 198/400 - Elapsed Time 1063.412803 - Remaining Time 1084.895890
# Epoch 199/400 - Elapsed Time 1068.691973 - Remaining Time 1079.432596
# Epoch 200/400 - Elapsed Time 1073.888776 - Remaining Time 1073.888776
# Epoch 201/400 - Elapsed Time 1079.219637 - Remaining Time 1068.481133
# Epoch 202/400 - Elapsed Time 1084.393913 - Remaining Time 1062.920766
# Epoch 203/400 - Elapsed Time 1089.552757 - Remaining Time 1057.349227
# Epoch 204/400 - Elapsed Time 1095.347425 - Remaining Time 1052.392624
# Epoch 205/400 - Elapsed Time 1100.889040 - Remaining Time 1047.187135
# Epoch 206/400 - Elapsed Time 1106.009318 - Remaining Time 1041.581591
# Epoch 207/400 - Elapsed Time 1111.282921 - Remaining Time 1036.123690
# Epoch 208/400 - Elapsed Time 1116.307786 - Remaining Time 1030.437957
# Epoch 209/400 - Elapsed Time 1121.394365 - Remaining Time 1024.814946
# Epoch 210/400 - Elapsed Time 1126.843307 - Remaining Time 1019.524897
# Epoch 211/400 - Elapsed Time 1132.567849 - Remaining Time 1014.480206
# Epoch 212/400 - Elapsed Time 1139.982633 - Remaining Time 1010.927995
# Epoch 213/400 - Elapsed Time 1145.269263 - Remaining Time 1005.471137
# Epoch 214/400 - Elapsed Time 1150.444888 - Remaining Time 999.919389
# Epoch 215/400 - Elapsed Time 1155.614988 - Remaining Time 994.366385
# Epoch 216/400 - Elapsed Time 1160.705035 - Remaining Time 988.748733
# Epoch 217/400 - Elapsed Time 1165.857471 - Remaining Time 983.188559
# Epoch 218/400 - Elapsed Time 1171.247518 - Remaining Time 977.830497
# Epoch 219/400 - Elapsed Time 1177.048823 - Remaining Time 972.812041
# Epoch 220/400 - Elapsed Time 1182.446707 - Remaining Time 967.456397
# Epoch 221/400 - Elapsed Time 1187.548991 - Remaining Time 961.860948
# Epoch 222/400 - Elapsed Time 1192.968954 - Remaining Time 956.524656
# Epoch 223/400 - Elapsed Time 1198.765450 - Remaining Time 951.486478
# Epoch 224/400 - Elapsed Time 1204.036843 - Remaining Time 946.028948
# Epoch 225/400 - Elapsed Time 1209.154679 - Remaining Time 940.453639
# Epoch 226/400 - Elapsed Time 1214.577438 - Remaining Time 935.117143
# Epoch 227/400 - Elapsed Time 1219.684705 - Remaining Time 929.539444
# Epoch 228/400 - Elapsed Time 1224.874585 - Remaining Time 924.028196
# Epoch 229/400 - Elapsed Time 1230.381479 - Remaining Time 918.756476
# Epoch 230/400 - Elapsed Time 1235.465462 - Remaining Time 913.170124
# Epoch 231/400 - Elapsed Time 1241.007209 - Remaining Time 907.923023
# Epoch 232/400 - Elapsed Time 1246.598195 - Remaining Time 902.709037
# Epoch 233/400 - Elapsed Time 1252.288429 - Remaining Time 897.562952
# Epoch 234/400 - Elapsed Time 1258.130473 - Remaining Time 892.519908
# Epoch 235/400 - Elapsed Time 1263.263640 - Remaining Time 886.972343
# Epoch 236/400 - Elapsed Time 1268.441846 - Remaining Time 881.459588
# Epoch 237/400 - Elapsed Time 1273.610523 - Remaining Time 875.943102
# Epoch 238/400 - Elapsed Time 1278.764257 - Remaining Time 870.419368
# Epoch 239/400 - Elapsed Time 1283.899204 - Remaining Time 864.886075
# Epoch 240/400 - Elapsed Time 1289.156839 - Remaining Time 859.437893
# Epoch 241/400 - Elapsed Time 1294.260574 - Remaining Time 853.889756
# Epoch 242/400 - Elapsed Time 1299.416721 - Remaining Time 848.379512
# Epoch 243/400 - Elapsed Time 1304.859031 - Remaining Time 843.057070
# Epoch 244/400 - Elapsed Time 1310.601856 - Remaining Time 837.925777
# Epoch 245/400 - Elapsed Time 1315.971532 - Remaining Time 832.553418
# Epoch 246/400 - Elapsed Time 1321.099408 - Remaining Time 827.029711
# Epoch 247/400 - Elapsed Time 1326.327204 - Remaining Time 821.571102
# Epoch 248/400 - Elapsed Time 1331.693569 - Remaining Time 816.199284
# Epoch 249/400 - Elapsed Time 1337.414665 - Remaining Time 811.042628
# Epoch 250/400 - Elapsed Time 1342.994632 - Remaining Time 805.796779
# Epoch 251/400 - Elapsed Time 1348.238637 - Remaining Time 800.348832
# Epoch 252/400 - Elapsed Time 1353.559996 - Remaining Time 794.947934
# Epoch 253/400 - Elapsed Time 1358.795210 - Remaining Time 789.497612
# Epoch 254/400 - Elapsed Time 1364.267471 - Remaining Time 784.185239
# Epoch 255/400 - Elapsed Time 1369.863281 - Remaining Time 778.941865
# Epoch 256/400 - Elapsed Time 1375.352776 - Remaining Time 773.635936
# Epoch 257/400 - Elapsed Time 1380.593246 - Remaining Time 768.190016
# Epoch 258/400 - Elapsed Time 1385.791389 - Remaining Time 762.722392
# Epoch 259/400 - Elapsed Time 1390.948304 - Remaining Time 757.234405
# Epoch 260/400 - Elapsed Time 1395.996750 - Remaining Time 751.690558
# Epoch 261/400 - Elapsed Time 1401.434654 - Remaining Time 746.357919
# Epoch 262/400 - Elapsed Time 1406.648772 - Remaining Time 740.906605
# Epoch 263/400 - Elapsed Time 1412.008233 - Remaining Time 735.532806
# Epoch 264/400 - Elapsed Time 1417.910045 - Remaining Time 730.438508
# Epoch 265/400 - Elapsed Time 1425.903479 - Remaining Time 726.403659
# Epoch 266/400 - Elapsed Time 1431.297404 - Remaining Time 721.029519
# Epoch 267/400 - Elapsed Time 1436.709435 - Remaining Time 715.664251
# Epoch 268/400 - Elapsed Time 1442.442617 - Remaining Time 710.456811
# Epoch 269/400 - Elapsed Time 1448.134955 - Remaining Time 705.225573
# Epoch 270/400 - Elapsed Time 1453.266354 - Remaining Time 699.720837
# Epoch 271/400 - Elapsed Time 1458.494453 - Remaining Time 694.264887
# Epoch 272/400 - Elapsed Time 1463.663460 - Remaining Time 688.782805
# Epoch 273/400 - Elapsed Time 1468.801856 - Remaining Time 683.288775
# Epoch 274/400 - Elapsed Time 1474.016455 - Remaining Time 677.832384
# Epoch 275/400 - Elapsed Time 1479.542419 - Remaining Time 672.519282
# Epoch 276/400 - Elapsed Time 1484.680176 - Remaining Time 667.030224
# Epoch 277/400 - Elapsed Time 1489.788235 - Remaining Time 661.530516
# Epoch 278/400 - Elapsed Time 1495.662151 - Remaining Time 656.369721
# Epoch 279/400 - Elapsed Time 1501.478398 - Remaining Time 651.178803
# Epoch 280/400 - Elapsed Time 1506.774622 - Remaining Time 645.760552
# Epoch 281/400 - Elapsed Time 1511.901440 - Remaining Time 640.271428
# Epoch 282/400 - Elapsed Time 1517.187787 - Remaining Time 634.851627
# Epoch 283/400 - Elapsed Time 1522.364920 - Remaining Time 629.387617
# Epoch 284/400 - Elapsed Time 1527.426598 - Remaining Time 623.878470
# Epoch 285/400 - Elapsed Time 1532.704048 - Remaining Time 618.459528
# Epoch 286/400 - Elapsed Time 1538.481673 - Remaining Time 613.240947
# Epoch 287/400 - Elapsed Time 1543.818498 - Remaining Time 607.844914
# Epoch 288/400 - Elapsed Time 1549.909844 - Remaining Time 602.742717
# Epoch 289/400 - Elapsed Time 1555.331293 - Remaining Time 597.376379
# Epoch 290/400 - Elapsed Time 1560.689323 - Remaining Time 591.985605
# Epoch 291/400 - Elapsed Time 1566.120105 - Remaining Time 586.622307
# Epoch 292/400 - Elapsed Time 1571.745350 - Remaining Time 581.330472
# Epoch 293/400 - Elapsed Time 1577.735996 - Remaining Time 576.169801
# Epoch 294/400 - Elapsed Time 1583.189069 - Remaining Time 570.809664
# Epoch 295/400 - Elapsed Time 1588.548294 - Remaining Time 565.415495
# Epoch 296/400 - Elapsed Time 1593.966592 - Remaining Time 560.042316
# Epoch 297/400 - Elapsed Time 1599.380132 - Remaining Time 554.667184
# Epoch 298/400 - Elapsed Time 1604.554810 - Remaining Time 549.210036
# Epoch 299/400 - Elapsed Time 1609.681544 - Remaining Time 543.738582
# Epoch 300/400 - Elapsed Time 1615.013365 - Remaining Time 538.337788
# Epoch 301/400 - Elapsed Time 1620.035601 - Remaining Time 532.835629
# Epoch 302/400 - Elapsed Time 1625.259444 - Remaining Time 527.402071
# Epoch 303/400 - Elapsed Time 1630.607595 - Remaining Time 522.009692
# Epoch 304/400 - Elapsed Time 1635.673434 - Remaining Time 516.528453
# Epoch 305/400 - Elapsed Time 1640.800681 - Remaining Time 511.069065
# Epoch 306/400 - Elapsed Time 1645.904003 - Remaining Time 505.604498
# Epoch 307/400 - Elapsed Time 1651.490748 - Remaining Time 500.288728
# Epoch 308/400 - Elapsed Time 1657.385728 - Remaining Time 495.063269
# Epoch 309/400 - Elapsed Time 1663.292953 - Remaining Time 489.837083
# Epoch 310/400 - Elapsed Time 1668.394137 - Remaining Time 484.372491
# Epoch 311/400 - Elapsed Time 1673.489299 - Remaining Time 478.908513
# Epoch 312/400 - Elapsed Time 1678.596996 - Remaining Time 473.450435
# Epoch 313/400 - Elapsed Time 1683.804236 - Remaining Time 468.022264
# Epoch 314/400 - Elapsed Time 1688.831352 - Remaining Time 462.546167
# Epoch 315/400 - Elapsed Time 1693.971194 - Remaining Time 457.103338
# Epoch 316/400 - Elapsed Time 1699.482194 - Remaining Time 451.761090
# Epoch 317/400 - Elapsed Time 1706.879912 - Remaining Time 446.911775
# Epoch 318/400 - Elapsed Time 1712.067182 - Remaining Time 441.476443
# Epoch 319/400 - Elapsed Time 1717.533467 - Remaining Time 436.113514
# Epoch 320/400 - Elapsed Time 1722.606843 - Remaining Time 430.651711
# Epoch 321/400 - Elapsed Time 1727.744805 - Remaining Time 425.208223
# Epoch 322/400 - Elapsed Time 1732.873635 - Remaining Time 419.764421
# Epoch 323/400 - Elapsed Time 1738.820078 - Remaining Time 414.517480
# Epoch 324/400 - Elapsed Time 1744.370829 - Remaining Time 409.173404
# Epoch 325/400 - Elapsed Time 1750.111017 - Remaining Time 403.871773
# Epoch 326/400 - Elapsed Time 1755.898685 - Remaining Time 398.578229
# Epoch 327/400 - Elapsed Time 1761.090176 - Remaining Time 393.148571
# Epoch 328/400 - Elapsed Time 1766.563398 - Remaining Time 387.782209
# Epoch 329/400 - Elapsed Time 1771.748949 - Remaining Time 382.353117
# Epoch 330/400 - Elapsed Time 1777.273738 - Remaining Time 376.997460
# Epoch 331/400 - Elapsed Time 1782.367405 - Remaining Time 371.550909
# Epoch 332/400 - Elapsed Time 1787.443139 - Remaining Time 366.102812
# Epoch 333/400 - Elapsed Time 1792.534921 - Remaining Time 360.660179
# Epoch 334/400 - Elapsed Time 1797.608990 - Remaining Time 355.216148
# Epoch 335/400 - Elapsed Time 1802.787982 - Remaining Time 349.794683
# Epoch 336/400 - Elapsed Time 1807.999380 - Remaining Time 344.380834
# Epoch 337/400 - Elapsed Time 1813.296462 - Remaining Time 338.984205
# Epoch 338/400 - Elapsed Time 1819.506891 - Remaining Time 333.755702
# Epoch 339/400 - Elapsed Time 1825.203091 - Remaining Time 328.428875
# Epoch 340/400 - Elapsed Time 1830.432560 - Remaining Time 323.017511
# Epoch 341/400 - Elapsed Time 1835.777611 - Remaining Time 317.627211
# Epoch 342/400 - Elapsed Time 1841.018027 - Remaining Time 312.219431
# Epoch 343/400 - Elapsed Time 1846.320393 - Remaining Time 306.822923
# Epoch 344/400 - Elapsed Time 1851.803435 - Remaining Time 301.456373
# Epoch 345/400 - Elapsed Time 1857.364194 - Remaining Time 296.101538
# Epoch 346/400 - Elapsed Time 1862.759626 - Remaining Time 290.719710
# Epoch 347/400 - Elapsed Time 1867.879089 - Remaining Time 285.295653
# Epoch 348/400 - Elapsed Time 1873.073226 - Remaining Time 279.884505
# Epoch 349/400 - Elapsed Time 1878.567164 - Remaining Time 274.518411
# Epoch 350/400 - Elapsed Time 1883.654648 - Remaining Time 269.093521
# Epoch 351/400 - Elapsed Time 1888.931189 - Remaining Time 263.696947
# Epoch 352/400 - Elapsed Time 1894.209666 - Remaining Time 258.301318
# Epoch 353/400 - Elapsed Time 1899.971494 - Remaining Time 252.970709
# Epoch 354/400 - Elapsed Time 1905.376493 - Remaining Time 247.591296
# Epoch 355/400 - Elapsed Time 1910.514182 - Remaining Time 242.177854
# Epoch 356/400 - Elapsed Time 1915.699749 - Remaining Time 236.771879
# Epoch 357/400 - Elapsed Time 1920.809155 - Remaining Time 231.357965
# Epoch 358/400 - Elapsed Time 1925.945080 - Remaining Time 225.948864
# Epoch 359/400 - Elapsed Time 1931.200616 - Remaining Time 220.554945
# Epoch 360/400 - Elapsed Time 1936.516143 - Remaining Time 215.168460
# Epoch 361/400 - Elapsed Time 1941.763054 - Remaining Time 209.774956
# Epoch 362/400 - Elapsed Time 1947.001731 - Remaining Time 204.381397
# Epoch 363/400 - Elapsed Time 1952.340340 - Remaining Time 198.998878
# Epoch 364/400 - Elapsed Time 1957.439129 - Remaining Time 193.592881
# Epoch 365/400 - Elapsed Time 1962.777229 - Remaining Time 188.211515
# Epoch 366/400 - Elapsed Time 1968.115022 - Remaining Time 182.830357
# Epoch 367/400 - Elapsed Time 1973.378563 - Remaining Time 177.442759
# Epoch 368/400 - Elapsed Time 1979.125474 - Remaining Time 172.097867
# Epoch 369/400 - Elapsed Time 1984.886014 - Remaining Time 166.751942
# Epoch 370/400 - Elapsed Time 1992.403839 - Remaining Time 161.546257
# Epoch 371/400 - Elapsed Time 1997.582261 - Remaining Time 156.145244
# Epoch 372/400 - Elapsed Time 2002.803843 - Remaining Time 150.748676
# Epoch 373/400 - Elapsed Time 2007.942340 - Remaining Time 145.347033
# Epoch 374/400 - Elapsed Time 2013.055436 - Remaining Time 139.945030
# Epoch 375/400 - Elapsed Time 2018.238277 - Remaining Time 134.549218
# Epoch 376/400 - Elapsed Time 2023.333325 - Remaining Time 129.148936
# Epoch 377/400 - Elapsed Time 2028.602197 - Remaining Time 123.760877
# Epoch 378/400 - Elapsed Time 2033.756551 - Remaining Time 118.366783
# Epoch 379/400 - Elapsed Time 2038.794579 - Remaining Time 112.967510
# Epoch 380/400 - Elapsed Time 2044.226545 - Remaining Time 107.590871
# Epoch 381/400 - Elapsed Time 2049.674761 - Remaining Time 102.214752
# Epoch 382/400 - Elapsed Time 2054.899508 - Remaining Time 96.827725
# Epoch 383/400 - Elapsed Time 2060.721082 - Remaining Time 91.468038
# Epoch 384/400 - Elapsed Time 2066.687487 - Remaining Time 86.111979
# Epoch 385/400 - Elapsed Time 2071.966443 - Remaining Time 80.725965
# Epoch 386/400 - Elapsed Time 2077.191562 - Remaining Time 75.338554
# Epoch 387/400 - Elapsed Time 2082.458952 - Remaining Time 69.953401
# Epoch 388/400 - Elapsed Time 2087.943549 - Remaining Time 64.575574
# Epoch 389/400 - Elapsed Time 2093.014496 - Remaining Time 59.185500
# Epoch 390/400 - Elapsed Time 2098.415200 - Remaining Time 53.805518
# Epoch 391/400 - Elapsed Time 2103.795115 - Remaining Time 48.424951
# Epoch 392/400 - Elapsed Time 2109.156215 - Remaining Time 43.044004
# Epoch 393/400 - Elapsed Time 2114.429311 - Remaining Time 37.661591
# Epoch 394/400 - Elapsed Time 2119.663499 - Remaining Time 32.279140
# Epoch 395/400 - Elapsed Time 2125.034515 - Remaining Time 26.899171
# Epoch 396/400 - Elapsed Time 2130.170448 - Remaining Time 21.516873
# Epoch 397/400 - Elapsed Time 2135.219076 - Remaining Time 16.135157
# Epoch 398/400 - Elapsed Time 2141.034626 - Remaining Time 10.758968
# Epoch 399/400 - Elapsed Time 2146.505198 - Remaining Time 5.379712
# Epoch 400/400 - Elapsed Time 2151.646829 - Remaining Time 0.000000

# %% [markdown]
# The next block will run prediction on the test set and save the output detections

# %%
from __future__ import division
from __future__ import print_function

import numpy as np
import torch
from torch.utils.data import DataLoader
from torchvision import transforms

from hourglass import hg

from dataset import Dataset
from dataset import CropAndPad, LocsToHeatmaps, ToTensor, Normalize
from tqdm import tqdm

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = hg(num_stacks=1, num_blocks=1, num_classes=10).to(device)
checkpoint = torch.load('/content/gdrive/My Drive/cis580-2019-hw6/model_checkpoint.pt')
model.load_state_dict(checkpoint['model'])
transform_list = [CropAndPad(out_size=(256, 256))]
transform_list.append(LocsToHeatmaps(out_size=(64,64)))
transform_list.append(ToTensor())
transform_list.append(Normalize())
test_ds = Dataset(is_train=False, transform=transforms.Compose(transform_list))
data_loader = DataLoader(test_ds, batch_size=1, pin_memory=True, shuffle=False)
predicted_heatmaps = np.zeros((len(test_ds), 10, 64, 64))
for i, batch in enumerate(tqdm(data_loader)):
    model.eval()
    images = batch['image'].to(device)
    with torch.no_grad():
        pred_heatmap_list = model(images)
    pred_heatmaps = pred_heatmap_list[-1]
    predicted_heatmaps[i,:,:,:] = pred_heatmaps[0,:,:,:].cpu().numpy()
np.save('/content/gdrive/My Drive/cis580-2019-hw6/detections.npy', predicted_heatmaps)
# Out:
# 100%|██████████| 27/27 [00:00<00:00, 28.39it/s]

# %% [markdown]
# Import the external and given functions for step 2

# %%
import numpy as np
import torch
import torch.nn as nn
import cv2
import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt
import os
from os.path import join
from utils import plot_mesh

"""
Convert axis-angle representation to a 3x3 rotation matrix
"""
class Rodrigues(torch.autograd.Function):
    @staticmethod
    def forward(self, inp):
        pose = inp.detach().cpu().numpy()
        rotm, part_jacob = cv2.Rodrigues(pose)
        self.jacob = torch.Tensor(np.transpose(part_jacob)).contiguous()
        rotation_matrix = torch.Tensor(rotm.ravel())
        return rotation_matrix.view(3,3)

    @staticmethod
    def backward(self, grad_output):
        grad_output = grad_output.view(1,-1)
        grad_input = torch.mm(grad_output, self.jacob)
        grad_input = grad_input.view(-1)
        return grad_input
"""
This is the function you should call to convert fom axis-angle to a rotation matrix
Example usage:
    aa = torch.zeros(3)
    R = rodrigues(aa)
"""
rodrigues = Rodrigues.apply

# %% [markdown]
# Step 2) Implement pose_optimization and heatmaps_to_locs as specified by the accompanying PDF

# %%
"""
YOU NEED TO IMPLEMENT THIS
Input: image, mesh vertices, mesh faces, detected 2d keypoints, keypoint confidences, 3D keypoint coordinates in the canonical position, intrinsic camera matrix
Output: R, t
"""
def pose_optimization(img, vertices, faces, keypoints_2d, conf, keypoints_3d, K):
    # Send variables to GPU
    device = keypoints_2d.device
    keypoints_3d = keypoints_3d.to(device)
    K = K.to(device)
    r = torch.rand(3, requires_grad=True, device=device) # rotation in axis-angle representation
    t = torch.rand(3 ,requires_grad=True, device=device)
    d = conf.sqrt()[:, None]
    # 2D keypoints in normalized coordinates
    norm_keypoints_2d = torch.matmul(K.inverse(), torch.cat((keypoints_2d, torch.ones(keypoints_2d.shape[0],1, device=device)), dim=-1).t()).t()[:,:-1]
    # set up optimizer
    optimizer = torch.optim.Adam([r,t], lr=1e-2)
    # converge check
    converged = False
    rel_tol = 1e-5
    loss_old = 100
    W = norm_keypoints_2d.transpose(1,0)
    D = torch.mul(d,d)
    i = 0
    while not converged:
        optimizer.zero_grad()
        # convert axis-angle to rotation matrix
        R = rodrigues(r)
        # 1) Compute projected keypoints based on current estimate of R and t
        P = torch.matmul(R,keypoints_3d.transpose(1,0)) + t[:,None]
        proj_keypoints = torch.div(P[0:2],P[2])
        # 2) Compute error (based on distance between projected keypoints and detected keypoints)
        e = torch.sum((W - proj_keypoints)**2,dim=0)
        loss = torch.matmul(e,D)
        # 3) Update based on error
        loss.backward()
        optimizer.step()
        # 4) Check for convergence
        i += 1
        rel_loss = torch.abs((loss_old-loss)/loss)
        if rel_loss < rel_tol:
            print(i)
            converged = True
        else:
            loss_old = loss
            
    proj_keypoints = proj_keypoints.transpose(1,0)
    R = rodrigues(r)
    plt.figure()
    plot_mesh(img, vertices, faces, R.detach().cpu().numpy(), t.detach().cpu().numpy()[:,None], K.detach().cpu().numpy())
    pk = torch.matmul(K, torch.cat((proj_keypoints, torch.ones(proj_keypoints.shape[0], 1, device=device)), dim=-1).t()).t()
    pk = pk.detach().cpu().numpy()
    plt.scatter(pk[:,0], pk[:,1], color='r')
    plt.show()
    return rodrigues(r)[0].detach(), t.detach()

"""
YOU NEED TO IMPLEMENT THIS
Convert heatmaps to 2D locations
Input: Nx10x64x64 keypoint heatmaps
Output: Nx10x3 keypoint locations and detection confidence (magnitude of the highest activation)
"""
def heatmaps_to_locs(heatmaps):
    valuesY , indexY = torch.max(heatmaps,2)
    valuesX , indexX = torch.max(valuesY,2)
    m = torch.zeros((indexX.shape[0],indexX.shape[1],3))
    for i in range(indexX.shape[0]):
        for j in range(indexX.shape[1]):
            m[i,j,0] = indexX[i,j]
            m[i,j,1] = indexY[i,j, indexX[i,j]]
            m[i,j,2] = valuesX[i,j]
    return m

# %% [markdown]
# The next block will start the pose optimization process. Be sure to run the above block first every time you want to test changes to the code.

# %%
data = np.load('data/misc_data.npz')
K = torch.from_numpy(data['K']).float()
S = torch.from_numpy(np.load('data/kpt.npy'))
vertices = data['vertices']
faces = data['faces']

dataset = np.load('data/valid_data.npz')
imgnames = dataset['imgname']
scales = torch.from_numpy(dataset['scale']).float()[:,None]
centers = torch.from_numpy(dataset['center']).float()
# detections.npy contains the detections saved after training your model and running predict.py
heatmaps = torch.from_numpy(np.load('/content/gdrive/My Drive/cis580-2019-hw6/detections.npy'))

keypoint_locs = heatmaps_to_locs(heatmaps)

# Compute detected 2D keypoint locations in the original image
ul_corner = centers - scales * 100
keypoint_locs[:,:,:-1] *= scales[:,:,None]*200 / 64
keypoint_locs[:,:,:-1] += ul_corner[:,None,:]

images = np.load('data/images.npz')

os.makedirs('/content/gdrive/My Drive/cis580-2019-hw6/pose_optimization', exist_ok=True)
for i in range(len(heatmaps)):
    img_name = imgnames[i].decode('utf-8')
    print("Processing ", img_name)
    img = images[img_name]
    pose_optimization(img, vertices, faces, keypoint_locs[i,:,:-1], keypoint_locs[i,:,-1], S, K)
    plt.savefig('/content/gdrive/My Drive/cis580-2019-hw6/pose_optimization/%s' % img_name, dpi=300)
    plt.close('all')
# Out:
# Processing  train_148.jpg
# 6487
# Processing  train_160.jpg
# 2634
# Processing  train_80.jpg
# 2267
# Processing  train_181.jpg
# 1336
# Processing  train_176.jpg
# 2723
# Processing  train_2.jpg
# 2726
# Processing  train_155.jpg
# 1262
# Processing  train_136.jpg
# 7517
# Processing  train_4.jpg
# 3854
# Processing  train_18.jpg
# 955
# Processing  train_106.jpg
# 4958
# Processing  train_90.jpg
# 1856
# Processing  train_25.jpg
# 2409
# Processing  train_116.jpg
# 884
# Processing  train_190.jpg
# 6301
# Processing  train_177.jpg
# 1738
# Processing  train_52.jpg
# 521
# Processing  train_191.jpg
# 6414
# Processing  train_13.jpg
# 2088
# Processing  train_9.jpg
# 2380
# Processing  train_81.jpg
# 1039
# Processing  train_21.jpg
# 1918
# Processing  train_72.jpg
# 3379
# Processing  train_144.jpg
# 1560
# Processing  train_10.jpg
# 6602
# Processing  train_12.jpg
# 1504
# Processing  train_140.jpg
# 3458
